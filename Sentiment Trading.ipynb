# %% [markdown]
# # Objectives
# * Classify tweets as bullish, neutral or bearish for a particular asset
# * Use classified tweets to build and backtest a trading strategy
#
# Consider model assumptions

# %% [markdown]
# # 0. Setup

# %%
# !pip install GetOldTweets3 #Some documentation at https://github.com/Mottl/GetOldTweets3

import pandas as pd
import GetOldTweets3 as got
from datetime import datetime, date

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
# Out:
# Collecting GetOldTweets3
#   Downloading https://files.pythonhosted.org/packages/ed/f4/a00c2a7c90801abc875325bb5416ce9090ac86d06a00cc887131bd73ba45/GetOldTweets3-0.0.11-py3-none-any.whl
# Collecting pyquery>=1.2.10
#   Downloading https://files.pythonhosted.org/packages/78/43/95d42e386c61cb639d1a0b94f0c0b9f0b7d6b981ad3c043a836c8b5bc68b/pyquery-1.4.1-py2.py3-none-any.whl
# Requirement already satisfied: lxml>=3.5.0 in /usr/local/lib/python3.6/dist-packages (from GetOldTweets3) (4.2.6)
# Collecting cssselect>0.7.9
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Installing collected packages: cssselect, pyquery, GetOldTweets3
# Successfully installed GetOldTweets3-0.0.11 cssselect-1.1.0 pyquery-1.4.1

# %% [markdown]
# # 1. Scraping tweets
# Things to consider when picking an asset:
# * Tweets per unit of time
# * Price movement over relevant time period. Has the price risen and fallen within the period, or has it moved in one direction?
# * Availability of price data
# * 'Quality' of tweets, judged on a small sample
#
# ---
#
# Some sources of time series data: Yahoo Finance, OFX, Federal Reserve, Investing.com

# %%
#Collecting tweets containing part or all of the string text_query
text_query = 'tsla'
count = 100 
#Creation of query object
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query)\
                                            .setMaxTweets(count)\
                                            .setTopTweets("True") #Greatly improves tweet quality, but much greater time difference between tweets (~2 days for 100 tweets vs ~2 mins for 100  for 'tesla')

#Creation of list that contains all tweets
tweets = got.manager.TweetManager.getTweets(tweetCriteria) #Creating list of chosen tweet data
text_tweets = [[tweet.date, tweet.text] for tweet in tweets] #Creation of dataframe from tweets list
tweets_df = pd.DataFrame(text_tweets)

# %%
#Tweets in sample
for t in tweets_df[1]:
  print (t)
# Out:
# If you’re confused about stocks. Trying to do it yourself. Did you know GK is one of the ONLY RIA firms with no minimums? You can have access to one of the fastest growing, most influential investment teams in finance. (Source @LABJnews ) http://GerberKawasaki.com $tsla #tesla
# Lenovo Legion x @PlayApex Now is your chance to rise above the rest. Unmatched performance, purposeful engineering, modern design. Gear up with a machine as savage as you are. Stylish outside. Savage inside.
# When the markets are closed, and you're worried you didn't buy enough $SPAQ $TSLA $WKHS $NIO
# Clean energy $SEDG $TSLA
# Could this be the bottom, or near the bottom of the Nasdaq? $VIX $VXN $NDX $QQQ $SPY $SPX $AAPL $NVDA $FB $TSLA $AMZN
# Tesla Should Not Be Valued as Car Company: Gerber - thoughts on tesla from Bloomberg TV today. $tsla ⁦@elonmusk⁩ https://www.bloomberg.com/news/videos/2020-09-12/tesla-should-not-be-valued-as-car-company-gerber-video
# $tsla LIFTOFF!!!!! $msft $aapl $tsla $nflx $fb $amzn $shop $goog $ebay $jnj $v $pg $jpm $unh $ma $intc $vz $hd $t $pfe $mrk $pep #DDTG $penn $pton DONT BET AGAINST @elonmusk
# $ADX Wow! Massive run! The next $ELF watch out for another 50% run easy low supply!! Keep stepping up 0.35 sooon!! $btc $link $yfi $yfii $sushi $eth $sxp $crv $dia $xlm $xrp $trx $ltc $kava $usdt $tsla $btt
# AAPL & TSLA new investors when they realized they bought the top.
# What defines a bubble? A great story is essential. In fact, the better the story the bigger the bubble. Then lots of liquidity and finally a classic bubble chart. For example, #bitcoin in 2017. In #TSLA we have all three.
# For those who are new to following my account: I rip on @TESLAcharts specifically because he: - Has terrible track record on all things $TSLA &amp; won't admit it - Is a liar - Has cost ppl a lot of money with his influence - Pushes the block list &amp; endorses censorship $TSLA
# $tsla LIFTOFF!!!!! BACK TO $502 $msft $aapl $tsla $nflx $fb $amzn $shop $goog $ebay $jnj $v $pg $jpm $unh $ma $intc $vz $hd $t $pfe $mrk $pep #DDTG $penn $pton DONT BET AGAINST @elonmusk @stoolpresidente @jimcramer STRAIGHT UP BATTERY DAY!
# If you’re confused about stocks. Trying to do it yourself. Did you know GK is one of the ONLY RIA firms with no minimums? You can have access to one of the fastest growing, most influential investment teams in finance. (Source @LABJnews ) http://GerberKawasaki.com $tsla #tesla
# When the markets are closed, and you're worried you didn't buy enough $SPAQ $TSLA $WKHS $NIO
# Clean energy $SEDG $TSLA
# Could this be the bottom, or near the bottom of the Nasdaq? $VIX $VXN $NDX $QQQ $SPY $SPX $AAPL $NVDA $FB $TSLA $AMZN
# Long term “don’t even look at” account $BABA 6% $AAPL 6% $AMZN 6% $FB 6% $MELI 6% $SE 6% $TSLA 6% $ZM 6% $ADBE 4% $CRWD 4% $DOCU 4% $FSLY 4% $LVGO 4% $SQ 4% $SBUX 4% $Z 4% $ZS 4% $CGC 3% $D 3% $PTON 3% $SHLL/ $HYLN 3% $SPAQ 1%
# The hive is made of two main parts: the Super at the top, where honey is stored and the brood box, where the queen lays eggs. Dr Bullock is holding one of the frames in the brood box. You can see thousands of worker bees (females).
# $DKNG getting ready to test ATH. $SPY $QQQ $TSLA $APPL
# Unlock more value from your prepared data with new write to database capabilities for Tableau Prep.
# The Next Frontier of Artificial Intelligence Predictability in Financial Markets https://www.streetinsider.com/dr/news.php?id=17324493 #StockMarket #stockstowatch $TSLA $AAPL #stockstobuy
# $tsla LIFTOFF!!!!! BACK TO $502 $msft $aapl $tsla $nflx $fb $amzn $shop $goog $ebay $jnj $v $pg $jpm $unh $ma $intc $vz $hd $t $pfe $mrk $pep #DDTG $penn $pton DONT BET AGAINST @elonmusk @stoolpresidente @jimcramer STRAIGHT UP!!!!!!!!
# People who didn't sell their TSLA stock at +250%
# Explore the latest Tableau 2020.3 product features for next-level security and scalability.
# Will $TSLA close above 365.07 level? Regardless, like this look on the 1hr going into Monday. Let's see what Elon has for us over the weekend
# #UnlockTheOpen with @Chase and make more of that energy felt at the @USOpen even as you watch from home. #ad
# $TSLA Tesla is in the highest Market cap in auto manufactures! look at the progress! Number talks!! New #Gigafactory will be the most Efficient Auto company of the world!! Revolution is here! Keep holding!!!
# The Best Penny Stock App #pennystock $HD $AMZN $MRNA $TSLA $LOW $VVV $SON $BA $NKE https://apps.apple.com/app/apple-store/id1454196854?pt=118022995&amp;ct=sim_twitter&amp;mt=8
# If You are looking for a Trading Chatroom where you can INTERACT with pro Trader & MENTORS Take a look at my bio $AAPL $AMZN $SPY $TSLA $NVDA $BABA $AMD $MSFT $NIO $SPCE $QCOM $BAC $SNAP $EXPE $PENN $AAL $UBER $NLS $WBA $DIS $PTON $NKLA $NKE $WMT $QQQ $MGM $ZM $VIX
# $TSLA party to end the week?
# Looking for a clear breakout here on $tsla
# The best performing stocks YTD with a market cap over $2 billion: 1. Novavax NVAX +2235% 2. Overstock OSTK +863% 3. WKHS +652% 4. Seres MCRB +609% 5. Zoom ZM +468% 6. Fiverr FIVR +446% 7. Liberty TripAdvisor LTRPB +428% 8. Livongo LVGO +395% 9. Tesla TSLA +343% 10. NIO +342%
# $AMZN $TSLA $AAPL $SPY Let's fucking go been banging out about $20k daily this week solid consistency pic.twitter.com/gqS8uTYfEL
# $TSLA I’m in this for the long ride
# #TSLA If we don't gain purple box i'll see you at white line - sorry #Tesla fans
# What people don’t realize is that it is impossible to start and successfully grow a new car company. After TSLA there is nothing left in me to go through all of that again and I wasn’t even sleeping on the factory floor #ElonMusk
# $NOVN i like the chart and the volume momentum trade here buying over $0.54 $TSLA $SQQQ $NIO $AAPL $CEMI
# I may look back and regret that I was not long enough...
# $VRUS afterhours sales.YES tomorrow $OZSC $TLSS $VYST $BBRW $GAXY $TOPS $TPTW $OPTI $PCTL $AAPL $CCTL $CTS $HTBX $BOXL $TSLA $MSFT $ABML $NAK $PMCB $BRTXQ $HTBX $TRIL $NIO $NKLA $STHC $ATDS $GNUS $RNWF $TSOI $ESYL $HEMP $ALYI $BANT $GEVO $AABB $CMGO $GHHC $SHLO $UNDR $M $AMZN
# $RH $WKHS $PTON show stocks can recover from the selloff and reach ATHs if $SPY 329 is the bottom, the next targets are found by taking the length of the prior advance and also the -78.6% Fib of the correction $SPY $ES_F 379-390 $QQQ $NQ_F 322-330 $AAPL 159 $TSLA 630 TimeT: 1M
# $IPOB bottomed at $12 Gap filled on the chart. Uptrend starting! LOADING ZONE! $NGA.U $BMRG $KCAC $SOAC $SPAQ $SHLL $HYLN $TSLA $NKLA $WKHS $NIO $FUV $WKHS $BLNK $FCEL $HCCH $GRAF $FVAC $LCA $FMCI $NFIN $OPES $CCXX $LACQ $DKNG $INSU $SNPR.U $FEAC $MNCL $SAMA $PSTH $APO #SPACS
# I would be stoked if I could buy back $TSLA under $200. #TESLA
# If you manage your risk, your profits will take care of itself. If you don't, your parents will take care of you. $TSLA $AAPL $AMZN $NVDA $MSFT $FB $AMD $DOCU $ZM $BABA
# Let's face it, some NBA draft picks get a failing grade.
# TM says $NKLA is a competitor for $TSLA. Is this like manifesting the future, or is it competing presently? Seems like for $GM and $BUD, this may be a write-off and riding hype for a respective breath of life.
# Grossly uncool kitchen decor only Baby Boomers still think is cool
# What's next? #TSLA
# "Stay Green Stay Tesla" It's called 'Greenorgasm!' Photo Credit: @teslaclubsocial #Tesla #TSLA #ElonMusk #space pic.twitter.com/EyTm2SV4Ri
# Today we removed the MAQs formic acid strips from the hive. These are important for killing nosema mites which can cause defects in the bees, including deformed wings. Smoking the hive calms the bees.
# Added se #RXMD yesterday on a friends suggestion. Already made some money and seeing good volume today. Great day $IBIO $TSLA $UPWT
# $TSLA YOUR CYBERTRUCK THIS SPRING 2021
# Some of the biggest premarket movers: $TSLA $PTON $OSTK
# $GM on the $NKLA deal $TSLA #TESLA
#  Stocks, Options, Swing Trading Welcome to http://discord.com/invite/VXJz5EG one of the largest stocks and options trading communities with real traders $GE $AAL $DIS $DAL $AAPL $MSFT $TSLA $SQ $NFLX $SPY $ROKU $SPCE $INO $UVXY $VXX $AAPL $TSLA
# $TSLA looking quite interesting... Comment your thoughts below!
# $VRUS chart looks amazing. BULLISH $OZSC $TLSS $VYST $BBRW $GAXY $TOPS $TPTW $OPTI $PCTL $AAPL $CCTL $CTS $HTBX $BOXL $TSLA $MSFT $ABML $NAK $PMCB $BRTXQ $HTBX $TRIL $NIO $NKLA $STHC $ATDS $GNUS $RNWF $TSOI $ESYL $HEMP $ALYI $BANT $GEVO $AABB $CMGO $GHHC $SHLO $UNDR $M $AMZN
# If you’re not buying #TSLA this week you hate money.
# $SPY 4,417 call contracts purchased at the $440 strike for December 31st today. $DKNG $TSLA $APPL $BA $QQQ $PYPL
# #tsla paying
# $CZNI let’s get back to .005+ before the merger PR. The sleeping giant of 2020. Currently .002 and looking for .05+ $SPY $TSLA $AMZN $AAPL $SHLL
# I’m showing you mine. Now show me yours.
# Pondering about $TSLA this week
# $TSLA CYBERTRUCK THIS SPRING 2021
# ya know the vibez >:) hehe #TSLA
# $TSLA vs Lumber .... what are we missing ?
# Think long-term. So many wonderful companies out there. Be smart and consistent. $NIO $TSLA
# Tomorrow’s #PlayoftheDay $LULU - $SPY $TSLA $QQQ $SHLL $LCA $FMCI
# $TSLA - Trade Idea - Sept 11th 385C Closed at 366.28 after reclaiming the key 359 level. If $TSLA can break above 368 tomorrow it can set up for a run to 384-400 next. -- $AMZN $AAPL $AMD $NFLX $BABA $FB $BA $NKLA $MSFT $ROKU $SPX $SPY $GOOGL $COST $WORK $ZM $NVDA $BYND
# Our service charges weekly because we don’t need a big upfront commitment from anyone. We know our service is legit. Numbers never lie. #DiamondClub $7/Week. $SPY $NKLA $SQ $AAPL $AMZN $HD $ZM $TSLA $OSTK $DOCU $ESTY $AMD $NVDA $QQQ $AAL $SLV $FB $SHOP $BYND $SPCE $WORK $NFLX
# Grossly uncool kitchen decor only Baby Boomers still think is cool
# Tomorrow’s Watchlist. Thoughts $TSLA $SPXL $TQQQ $UVXY $SPXS $SQQQ $LCA $FMCI $SHLL $HCAC $LOVE $LULU $GME
# $GLD seems to reject the support line at 180 a couple times, we should see a breakout within the coming weeks, grabbing a call at 180 is a good play and cut loss under 176 $SPY $QQQ $VIX $AAPL $TSLA $GLD $AMD $SLV $MSFT $AAL $ETSY $TWTR
# Stocks , Options , Day , swing Trade Welcome to http://discord.com/invite/VXJz5EG one of the largest stocks and options trading communities with real traders $GE $AAL $DIS $DAL $AAPL $MSFT $TSLA $SQ $NFLX $SPY $ROKU $SPCE $INO $UVXY $VXX $AAPL $TSLA
# Stocks in-play for today: $LULU $TRIL $ITCI $TSLA $NKLA $GM
# The folks who have been selling TSLA (except for the Tesla $5B raise) may face a lifetime of regret and depression. Keep your on the underlying business. TSLA should not be owned by anyone who is afraid of their own shadow.
# I call that a bargain, the best I’ve ever had
# Money in the making...! CALL OPTIONS $AAPL $TSLA $PLUG $LUV $CRBP
# Deposit $ANK and earn $TSLA NOW!
# “I could either watch it happen or be a part of it” Elon Musk $TSLA
# $AAPL and $TSLA charts
# $AAPL $TSLA $NASDAQ Silly bears https://www.investing.com/news/stock-market-news/nasdaq-notches-best-day-since-april-as-bears-flee-on-tech-rebound-2290735
# Important week: we have treated the hive for nosema mites using formic acid strips. This will keep the colony healthy through winter and prevent deformed wing development in the spring.
# $pk on watch adding more above 10.62 10.68 $tsla $amzn $aapl $nkla $spy $amd $nflx $nvda $qqq $vix $sqqq $Spxs $slv $roku $bynd $dis $crwd $mrna $mo $intc
#  Stocks, Options, Swing Trading Welcome to http://discord.com/invite/VXJz5EG one of the largest stocks and options trading communities with real traders $GE $AAL $DIS $DAL $AAPL $MSFT $TSLA $SQ $NFLX $SPY $ROKU $SPCE $INO $UVXY $VXX $AAPL $TSLA
# How to screw retail Wall Street style $TSLA
# If we see $PINS falls below that support line we can see it test the long term trend line, under 30 we can see it go to 27 $SPY $QQQ $VIX $AAPL $TSLA $ROKU $AMD $PTON $BYND $AAL $ETSY
# $AAPL $MSFT $TSLA $FB $GOOGL $GOOG $NFLX $AMZN $SPY $DOW $NQ Our outlook on Nasdaq! Break under 10900 invalidates this projection!
# 538.75 $tsla longs rn.
# Stocks were on sale today. What did you buy? $TSLA $APPL $AMZN
# Ark Invest bought $tsla and sold $aapl today! That's what I did as well
# $QQQ: 7,000 September 30th put contracts bought at $195 strike. Contracts are currently trading at $0.20. $SPY $TSLA $APPL $BA $NKLA
# $NKLA pick from Thursday goes 800% ROI today. $AAPL $MSFT $AMZN $FB $NFLX $GOOGL $AMD $NVDA $BYND $BA $BABA $DAL $WMT $COST $TSLA $QQQ $SPY $ZM
# $spy $qqq $aapl $msft $fb $amd $nvda $amzn $tsla how bad is it ?
# ARK Invest, Cathie Wood, trading activity for 9/8/2020: $ARKK $ARKQ $ARKW $ARKG $ARKF New Buy(s): None Significant Buy(s): $TSLA!!! $TWLO $CRWD Significant Sell(s): $AAPL! $PINS $VMW $ISRG
# $nio Great Wall of $17.00 holding strong compared to $tsla.... I’m a Tesla fan but talk about a tech bubble bursting. Gonna load more on $nio as I think we’ve hit rock bottom.
# My holdings at close $AAPL $TSLA $SSL $GPS $DIS #SPACs $SHLL $SPAQ $KCAC Calls $TSLA $PFE $MSFT $USO $USB Puts $AMRN Leaps $SPY $DAL Today reddest day ever because I’m $TSLA $AAPL heavy , all time green. The market today:
# I believe this so I will never let go of my shares. I kicked today in the but despite my losses today.
# not for the faint of heart #BTFD $TSLA $QQQ $SPY $AAPL
# If today’s stock market had a face... $AAPL $TPTW $MSFT $TSLA $ZHUD $BLXX
# I believe that the future will be bright - VERY
#
# Time difference between first and last tweet:  3 days 16:15:08

# %%
print ("\nTime difference between first and last tweet in sample: ", tweets_df[0][0] - tweets_df[0][99])
# Out:
# Time difference between first and last tweet in sample:  3 days 16:15:08

# %% [markdown]
# # 2. Preprocessing tweets
# The main objective of preprocessing is to reduce redundancy in our dictionary (the set of all words which appear at least once in some tweet in the sample).
#
# Here are some thoughts to guide preprocessing, from looking at the tweets above and https://www.analyticsvidhya.com/blog/2018/07/hands-on-sentiment-analysis-dataset-python/:
#
#
# * Exclamation marks, question marks,  fully capitalised words and hashtags can help classify tweets as neutral or non-neutral
# * Convert words with a leading capital to lowercase
# * Similarly we can try lemmatization (reduce words to their root, e.g. convert 'loves', 'loving', 'lovable', etc. to 'love') and stemming (remove suffixes such as 'ing', 'ed', 'ly', etc.)
# * Remove all other punctuation, special characters, URLs and numbers
# * Smaller words like 'and', 'are', 'is' and 'at' (stopwords) don't imply any obvious sentiment, so they can be removed
#
# See https://textblob.readthedocs.io/en/dev/index.html

# %% [markdown]
# # 3. Feature extraction and selection
# Here we extract and select the most representative features of the text by obtaining vector representations of our tweets.
#
# Resources:
# * https://arxiv.org/pdf/1908.10063.pdf (FinBERT)
# * https://arxiv.org/pdf/1711.05345.pdf (Unsupervised transfer learning, §2.2)
# * https://scikit-learn.org/stable/modules/feature_extraction.html#text-feature-extraction (API for BoW, TF-IDF)
# * http://jalammar.github.io/illustrated-bert/
#
# It's infeasible to train our own model for this task, so we'll use a pre-trained word embedding model. Word2Vec and GloVe are context insensitive, so we'll use ELMo or BERT instead.
#
# ---
#
# It seems like we could just use a pre-trained FinBERT model to accomplish tasks 3 and 4 in one step. We could try to use unsupervised transfer learning on a pre-trained BERT / FinBERT model to improve accuracy for our data.

# %%
from textblob import TextBlob

tweets_df[1][:5].apply(lambda x: TextBlob(x).sentiment)
# Out:
# 0                 (0.55, 0.75)
# 1                  (-0.2, 0.1)
# 2                   (0.8, 0.7)
# 3    (0.5, 0.8333333333333334)
# 4                   (0.0, 0.0)
# Name: 1, dtype: object

# %%
for s in range(0, 5):
  print (tweets_df[1][s])
# Out:
# dudes get around some girls and start talking about "you think I own too many Tesla shares??"
# If you can’t purchase the Tesla stock today, look into the companies that manufacture parts for the company. If Tesla is growing then so are the companies who are connected to them. Here are a few.
# Lol the Apple and Tesla stock split got Robinhood looking like the SNKRS app #StockTalk
# The sexual tension between me and the Apple and Tesla stock split
# Omg I’m up $3500 off a $500 investment on Apple and Tesla

# %% [markdown]
# # 4. Modelling
# We want to group unlabelled vector representations of tweets, so the obvious approach is to use a clustering algorithm (see https://developers.google.com/machine-learning/clustering/clustering-algorithms).

# %% [markdown]
# # 5. Backtesting
# We now have tweets labelled with sentiment. A possible approach is to group tweets by day, find the average sentiment of tweets for each day and use this to create a buy / hold / sell signal for each day. We can then align this vector of signals with a daily close price vector for the same asset and track performance based on a simple rule.
